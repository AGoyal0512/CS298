# %% [markdown]
# # Function that uses geocoding to extract latitude-longitude using address or zip-code:

# %%
with open('apikey.txt') as f:
    api_key = f.readline()
    f.close

# %%
import requests
GMAPS_API_KEY = api_key

# %%
def get_lat_long(address_or_zipcode):
    """
    This function can be used to extract the latitudinal and longitudinal
    coordinated of an entered address {as a string} or an entered zipcode 
    {as a number} and return (Latitude, Longitude)
    """

    lat, lng = None, None
    api_key = GMAPS_API_KEY
    
    # Setting up a base URL and an f-string to capture the position
    # Using the address and the API key
    base_url = "https://maps.googleapis.com/maps/api/geocode/json"
    position = f"{base_url}?address={address_or_zipcode}&key={api_key}"
    
    # Requesting that position from GoogleMaps
    r = requests.get(position)
    
    # If status code is not in valid range (ex. 404 - Not Found)
    # Return without extracting latitude-longitude information
    if r.status_code not in range(200, 299):
        return None, None
    
    # Otherwise extract the latitude-longitude information from the request response
    try:
        results = r.json()['results'][0]
        lat = results['geometry']['location']['lat']
        lng = results['geometry']['location']['lng']
    except:
        pass
    
    return lat, lng

# %%
address = 'Ogg Residence Hall, Madison, Wisconsin'
get_lat_long(address)
# Out:
# (43.070549, -89.399936)

# %%
address = "Greenwich, London"
get_lat_long(address)
# Out:
# (51.4933675, 0.0098214)

# %%
address = "Berlin, Germany"
get_lat_long(address)
# Out:
# (52.52000659999999, 13.404954)

# %%
address = "Cheesecake Factory, West Towne Mall, Madison, Wisconsin, USA"
get_lat_long(address)
# Out:
# (43.057573, -89.5048796)

# %%
import pandas as pd
data = pd.read_csv('cleaned_df.csv')
data
# Out:
#        IncidentID                                     IncidentType  \
# 0            7400  Assist Outside Agency
# 1            7401  Arrested Person
# 2            7402  Arrested Person
# 3            7403  Arrested Person
# 4            7404  Information
# ...           ...                                              ...
# 14131       28608                                          Robbery
# 14132       28609                               Attempted Homicide
# 14133       28610                                      Information
# 14134       28611                              Fight (In Progress)
# 14135       28612                                      Information
#
#                                               CaseNumber  \
# 0      2005-13680                                    ...
# 1      2005-22647                                    ...
# 2      2005-22345                                    ...
# 3      2005-22688                                    ...
# 4      2005-999999                                   ...
# ...                                                  ...
# 14131                                        2021-410423
# 14132                                        2021-407981
# 14133                                        2021-411747
# 14134                                        2021-412832
# 14135                                        0000-000000
#
#                                                  Suspect  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14131  Male described as 6 feet tall, slender, with a...
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                 Arrested  \
# 0                                                    ...
# 1      Tony R Markovitch, 20 years old, 301 Knutson D...
# 2      Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3      Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                     Tokiee D. Sole
# 14133                                                NaN
# 14134  Aaron Mixon, 24-year-old\r\n\r\nNathan Dougher...
# 14135                                                NaN
#
#                                                  Address  \
# 0      700 Block of E. Washington Ave., Madison, Wisc...
# 1        First St & E Washington Ave, Madison, Wisconsin
# 2                   8 New Berm Court, Madison, Wisconsin
# 3                     4300 Lumley Rd, Madison, Wisconsin
# 4              211 S. Carroll Street, Madison, Wisconsin
# ...                                                  ...
# 14131           3700 Frosted Leaf Dr, Madison, Wisconsin
# 14132           5800 block Balsam Rd, Madison, Wisconsin
# 14133          Esker Trl/Lilyview Ln, Madison, Wisconsin
# 14134                 200 N First St, Madison, Wisconsin
# 14135              1710 Mckenna Blvd, Madison, Wisconsin
#
#                                                   Victim  \
# 0                                                    ...
# 1      n/a                                           ...
# 2      Home Depot                                    ...
# 3      Adult male resident of Madison                ...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                  Details  \
# 0      On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1      At approximately 11:42 pm, an officer noted a ...
# 2      On 03/02/2005 at approximately 8:15 am, the Ma...
# 3      At approximately 7:30 am this date, Officers r...
# 4      DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                  ...
# 14131  Madison Police officers were dispatched to the...
# 14132  On 10/10/2021 at approximately 3:50 a.m., Madi...
# 14133  On October 12th, 2021 at approximately 6:43 PM...
# 14134  Madison Police Officers responded to 200 N Fir...
# 14135  The Madison Police Department’s West District ...
#
#                                      ReleasedBy  Day  Month  Year  Hour
# 0      Mike Hanson                                 7     10  2005     4
# 1      Lt Pat Malloy                               3      3  2005     6
# 2      Lt. T. Peterson                             2      3  2005    15
# 3      Lt. Pat Malloy                              3      3  2005    14
# 4      Lieutenant Joe Balles                       4      3  2005    20
# ...                                         ...  ...    ...   ...   ...
# 14131                    Lt. Michael Richardson   12     10  2021     7
# 14132                         P.O. Hunter Lisko   10     10  2021     9
# 14133                        PIO Julie Laundrie   12     10  2021    24
# 14134                       P.O. Ryan Kimberley   13     10  2021    22
# 14135                       P.O. Ryan Kimberley   14     10  2021     5
#
# [14136 rows x 13 columns]

# %%
import numpy as np
data['Lat'] = pd.Series(np.zeros(data.shape[0]))
data['Long'] = pd.Series(np.zeros(data.shape[0]))

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
for i in range(0,1000):
    
    address = data['Address'][i]
    
    data['Lat'][i] = get_lat_long(address)[0]
    data['Long'][i] = get_lat_long(address)[1]

# %%
for i in range(1000,2000):
    
    address = data['Address'][i]
    
    data['Lat'][i] = get_lat_long(address)[0]
    data['Long'][i] = get_lat_long(address)[1]

# %%
for i in range(2000,3000):
    
    address = data['Address'][i]
    
    data['Lat'][i] = get_lat_long(address)[0]
    data['Long'][i] = get_lat_long(address)[1]

# %%
data[:2999]
# Out:
#       IncidentID                                     IncidentType  \
# 0           7400  Assist Outside Agency
# 1           7401  Arrested Person
# 2           7402  Arrested Person
# 3           7403  Arrested Person
# 4           7404  Information
# ...          ...                                              ...
# 2994       10444                             Residential Burglary
# 2995       10445                             Residential Burglary
# 2996       10446                                          Robbery
# 2997       10447                                          Battery
# 2998       10448                               Intoxicated Driver
#
#                                              CaseNumber  \
# 0     2005-13680                                    ...
# 1     2005-22647                                    ...
# 2     2005-22345                                    ...
# 3     2005-22688                                    ...
# 4     2005-999999                                   ...
# ...                                                 ...
# 2994                                        2009-299238
# 2995                                        2009-297676
# 2996                                        2009-299895
# 2997                                        2009-299109
# 2998                                        2009-298056
#
#                                                 Suspect  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2994  Male, black, late teens, medium complexion, 5'...
# 2995  Male, black, 5'10" to 5'11", 40's, thin build,...
# 2996  Male, white, 6 feet, thin build, dark hair, bl...
# 2997  Male, white, 40's, 5'9", medium build, blonde ...
# 2998                                                NaN
#
#                                                Arrested  \
# 0                                                   ...
# 1     Tony R Markovitch, 20 years old, 301 Knutson D...
# 2     Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3     Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                   ...
# ...                                                 ...
# 2994                                                NaN
# 2995                                                NaN
# 2996                                                NaN
# 2997                                                NaN
# 2998  Christopher B. Bivens, age 22, Monona\r\nMr. B...
#
#                                                 Address  \
# 0     700 Block of E. Washington Ave., Madison, Wisc...
# 1       First St & E Washington Ave, Madison, Wisconsin
# 2                  8 New Berm Court, Madison, Wisconsin
# 3                    4300 Lumley Rd, Madison, Wisconsin
# 4             211 S. Carroll Street, Madison, Wisconsin
# ...                                                 ...
# 2994        1800 block Heath Avenue, Madison, Wisconsin
# 2995       500 block W. Doty Street, Madison, Wisconsin
# 2996  1305 Regent St (Greenbush Bakery), Madison, Wi...
# 2997   1200 block Williamson Street, Madison, Wisconsin
# 2998  200 block W. Beltline Highway, Madison, Wisconsin
#
#                                                  Victim  \
# 0                                                   ...
# 1     n/a                                           ...
# 2     Home Depot                                    ...
# 3     Adult male resident of Madison                ...
# 4                                                   ...
# ...                                                 ...
# 2994                                             Female
# 2995                              Male, age 20, Madison
# 2996                                   Greenbush Bakery
# 2997                              Male, age 27, Madison
# 2998                            Female, age 25, Madison
#
#                                                 Details  \
# 0     On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1     At approximately 11:42 pm, an officer noted a ...
# 2     On 03/02/2005 at approximately 8:15 am, the Ma...
# 3     At approximately 7:30 am this date, Officers r...
# 4     DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                 ...
# 2994  Around 8:00 a.m. this morning, a woman returne...
# 2995  On Sunday afternoon, a 20-year old Madison man...
# 2996  On Tuesday evening at approximately 7:15pm Mad...
# 2997  Early Tuesday morning, a 27-year old Madison m...
# 2998  Early Monday morning, a 25-year old Madison wo...
#
#                                     ReleasedBy  Day  Month  Year  Hour  \
# 0     Mike Hanson                                 7     10  2005     4
# 1     Lt Pat Malloy                               3      3  2005     6
# 2     Lt. T. Peterson                             2      3  2005    15
# 3     Lt. Pat Malloy                              3      3  2005    14
# 4     Lieutenant Joe Balles                       4      3  2005    20
# ...                                        ...  ...    ...   ...   ...
# 2994                          PIO Joel DeSpain    6     10  2009    13
# 2995                          PIO Joel DeSpain    4     10  2009    22
# 2996                       Sgt. Jason Ostrenga    7     10  2009     0
# 2997                          PIO Joel DeSpain    6     10  2009     6
# 2998                          PIO Joel DeSpain    5     10  2009     8
#
#             Lat        Long
# 0     43.079849  -89.377004
# 1     33.745647 -117.849324
# 2     43.039938  -89.503098
# 3     43.033631  -89.446744
# 4     43.072397  -89.382550
# ...         ...         ...
# 2994  43.119607  -89.361638
# 2995  43.068713  -89.388982
# 2996  43.067961  -89.410261
# 2997  43.083251  -89.364327
# 2998  43.041268  -89.380102
#
# [2999 rows x 15 columns]

# %%
data.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new
# Out:
#        IncidentID                                     IncidentType  \
# 0            7400  Assist Outside Agency
# 1            7401  Arrested Person
# 2            7402  Arrested Person
# 3            7403  Arrested Person
# 4            7404  Information
# ...           ...                                              ...
# 14131       28608                                          Robbery
# 14132       28609                               Attempted Homicide
# 14133       28610                                      Information
# 14134       28611                              Fight (In Progress)
# 14135       28612                                      Information
#
#                                               CaseNumber  \
# 0      2005-13680                                    ...
# 1      2005-22647                                    ...
# 2      2005-22345                                    ...
# 3      2005-22688                                    ...
# 4      2005-999999                                   ...
# ...                                                  ...
# 14131                                        2021-410423
# 14132                                        2021-407981
# 14133                                        2021-411747
# 14134                                        2021-412832
# 14135                                        0000-000000
#
#                                                  Suspect  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14131  Male described as 6 feet tall, slender, with a...
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                 Arrested  \
# 0                                                    ...
# 1      Tony R Markovitch, 20 years old, 301 Knutson D...
# 2      Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3      Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                     Tokiee D. Sole
# 14133                                                NaN
# 14134  Aaron Mixon, 24-year-old\r\n\r\nNathan Dougher...
# 14135                                                NaN
#
#                                                  Address  \
# 0      700 Block of E. Washington Ave., Madison, Wisc...
# 1        First St & E Washington Ave, Madison, Wisconsin
# 2                   8 New Berm Court, Madison, Wisconsin
# 3                     4300 Lumley Rd, Madison, Wisconsin
# 4              211 S. Carroll Street, Madison, Wisconsin
# ...                                                  ...
# 14131           3700 Frosted Leaf Dr, Madison, Wisconsin
# 14132           5800 block Balsam Rd, Madison, Wisconsin
# 14133          Esker Trl/Lilyview Ln, Madison, Wisconsin
# 14134                 200 N First St, Madison, Wisconsin
# 14135              1710 Mckenna Blvd, Madison, Wisconsin
#
#                                                   Victim  \
# 0                                                    ...
# 1      n/a                                           ...
# 2      Home Depot                                    ...
# 3      Adult male resident of Madison                ...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                  Details  \
# 0      On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1      At approximately 11:42 pm, an officer noted a ...
# 2      On 03/02/2005 at approximately 8:15 am, the Ma...
# 3      At approximately 7:30 am this date, Officers r...
# 4      DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                  ...
# 14131  Madison Police officers were dispatched to the...
# 14132  On 10/10/2021 at approximately 3:50 a.m., Madi...
# 14133  On October 12th, 2021 at approximately 6:43 PM...
# 14134  Madison Police Officers responded to 200 N Fir...
# 14135  The Madison Police Department’s West District ...
#
#                                      ReleasedBy  Day  Month  Year  Hour  \
# 0      Mike Hanson                                 7     10  2005     4
# 1      Lt Pat Malloy                               3      3  2005     6
# 2      Lt. T. Peterson                             2      3  2005    15
# 3      Lt. Pat Malloy                              3      3  2005    14
# 4      Lieutenant Joe Balles                       4      3  2005    20
# ...                                         ...  ...    ...   ...   ...
# 14131                    Lt. Michael Richardson   12     10  2021     7
# 14132                         P.O. Hunter Lisko   10     10  2021     9
# 14133                        PIO Julie Laundrie   12     10  2021    24
# 14134                       P.O. Ryan Kimberley   13     10  2021    22
# 14135                       P.O. Ryan Kimberley   14     10  2021     5
#
#              Lat        Long
# 0      43.079849  -89.377004
# 1      33.745647 -117.849324
# 2      43.039938  -89.503098
# 3      43.033631  -89.446744
# 4      43.072397  -89.382550
# ...          ...         ...
# 14131   0.000000    0.000000
# 14132   0.000000    0.000000
# 14133   0.000000    0.000000
# 14134   0.000000    0.000000
# 14135   0.000000    0.000000
#
# [14136 rows x 15 columns]

# %%
for i in range(3000,5000):
    
    address = data_new['Address'][i]
    
    data_new['Lat'][i] = get_lat_long(address)[0]
    data_new['Long'][i] = get_lat_long(address)[1]

# %%
data_new.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new[:5000]
# Out:
#       IncidentID                                     IncidentType  \
# 0           7400  Assist Outside Agency
# 1           7401  Arrested Person
# 2           7402  Arrested Person
# 3           7403  Arrested Person
# 4           7404  Information
# ...          ...                                              ...
# 4995       12459                                  Arrested Person
# 4996       12460                              Fight (In Progress)
# 4997       12461                                  Arrested Person
# 4998       12462                              Fight (In Progress)
# 4999       12463                               Intoxicated Driver
#
#                                              CaseNumber     Suspect  \
# 0     2005-13680                                    ...         NaN
# 1     2005-22647                                    ...         NaN
# 2     2005-22345                                    ...         NaN
# 3     2005-22688                                    ...         NaN
# 4     2005-999999                                   ...         NaN
# ...                                                 ...         ...
# 4995                                        2011-240349  see below:
# 4996                                        2011-236554  See below:
# 4997                                        2011-236218  See below:
# 4998                                        2011-235627  See Below:
# 4999                                        2011-238733  See Below:
#
#                                                Arrested  \
# 0                                                   ...
# 1     Tony R Markovitch, 20 years old, 301 Knutson D...
# 2     Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3     Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                   ...
# ...                                                 ...
# 4995  Miles E. Kristan, 25-year-old male of Madison,...
# 4996  Brendan Emon Kim, 21-year-old male of Cottage ...
# 4997  Quentin Romel Scott, 23-year-old male of Madis...
# 4998  Nicholas Alexander McQueen, 21-year-old male o...
# 4999  Mark W. Fields, 24-year-old male of Madison, W...
#
#                                                 Address  \
# 0     700 Block of E. Washington Ave., Madison, Wisc...
# 1       First St & E Washington Ave, Madison, Wisconsin
# 2                  8 New Berm Court, Madison, Wisconsin
# 3                    4300 Lumley Rd, Madison, Wisconsin
# 4             211 S. Carroll Street, Madison, Wisconsin
# ...                                                 ...
# 4995               700 State Street, Madison, Wisconsin
# 4996        300 West Johnson Street, Madison, Wisconsin
# 4997               1800 Beld Street, Madison, Wisconsin
# 4998               500 State Street, Madison, Wisconsin
# 4999              5800 Raymond Road, Madison, Wisconsin
#
#                                                  Victim  \
# 0                                                   ...
# 1     n/a                                           ...
# 2     Home Depot                                    ...
# 3     Adult male resident of Madison                ...
# 4                                                   ...
# ...                                                 ...
# 4995                                                NaN
# 4996                                                NaN
# 4997                                 19-year-old female
# 4998                                                NaN
# 4999                                                NaN
#
#                                                 Details  \
# 0     On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1     At approximately 11:42 pm, an officer noted a ...
# 2     On 03/02/2005 at approximately 8:15 am, the Ma...
# 3     At approximately 7:30 am this date, Officers r...
# 4     DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                 ...
# 4995  Madison Police went to the 700 block of State ...
# 4996  Madison Police responded to the 300 block of W...
# 4997  Madison Police responded to the 1800 block of ...
# 4998  On 8/21/2011, at approximately 2:25 am, Madiso...
# 4999  On 8/24/2011, at approximately 3:01am, a Madis...
#
#                                     ReleasedBy  Day  Month  Year  Hour  \
# 0     Mike Hanson                                 7     10  2005     4
# 1     Lt Pat Malloy                               3      3  2005     6
# 2     Lt. T. Peterson                             2      3  2005    15
# 3     Lt. Pat Malloy                              3      3  2005    14
# 4     Lieutenant Joe Balles                       4      3  2005    20
# ...                                        ...  ...    ...   ...   ...
# 4995                         P.O. Howard Payne   25      8  2011    21
# 4996                         P.O. Howard Payne   22      8  2011     7
# 4997                         P.O. Howard Payne   21      8  2011    23
# 4998                         P.O. Howard Payne   21      8  2011     7
# 4999                         P.O. Howard Payne   24      8  2011     8
#
#             Lat        Long
# 0     43.079849  -89.377004
# 1     33.745647 -117.849324
# 2     43.039938  -89.503098
# 3     43.033631  -89.446744
# 4     43.072397  -89.382550
# ...         ...         ...
# 4995  43.075564  -89.397376
# 4996  43.074558  -89.390674
# 4997  43.047977  -89.393348
# 4998  43.075055  -89.393463
# 4999  43.032214  -89.479869
#
# [5000 rows x 15 columns]

# %%
for i in range(5000,7000):
    
    address = data_new['Address'][i]
    
    data_new['Lat'][i] = get_lat_long(address)[0]
    data_new['Long'][i] = get_lat_long(address)[1]

# %%
data_new.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new[:7000]
# Out:
#       IncidentID                                     IncidentType  \
# 0           7400  Assist Outside Agency
# 1           7401  Arrested Person
# 2           7402  Arrested Person
# 3           7403  Arrested Person
# 4           7404  Information
# ...          ...                                              ...
# 6995       14466                                            Fraud
# 6996       14467                                          Battery
# 6997       14468                                 Traffic Incident
# 6998       14469                                Weapons Violation
# 6999       14470                                      Information
#
#                                              CaseNumber  \
# 0     2005-13680                                    ...
# 1     2005-22647                                    ...
# 2     2005-22345                                    ...
# 3     2005-22688                                    ...
# 4     2005-999999                                   ...
# ...                                                 ...
# 6995                                        2013-183171
# 6996                                        2013-167555
# 6997                                        2013-185256
# 6998                                        2013-188127
# 6999                                        2013-000000
#
#                            Suspect  \
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 6995                           NaN
# 6996                           NaN
# 6997  Possibly a black Volkswagen.
# 6998                           NaN
# 6999                           NaN
#
#                                                Arrested  \
# 0                                                   ...
# 1     Tony R Markovitch, 20 years old, 301 Knutson D...
# 2     Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3     Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                   ...
# ...                                                 ...
# 6995  Dangelo D. Chester, age 24, Chicago\r\nMr. Che...
# 6996  Jakiv McReynolds, age 18, Madison\r\nMr. McRey...
# 6997                                                NaN
# 6998                                                NaN
# 6999                                                NaN
#
#                                                 Address  \
# 0     700 Block of E. Washington Ave., Madison, Wisc...
# 1       First St & E Washington Ave, Madison, Wisconsin
# 2                  8 New Berm Court, Madison, Wisconsin
# 3                    4300 Lumley Rd, Madison, Wisconsin
# 4             211 S. Carroll Street, Madison, Wisconsin
# ...                                                 ...
# 6995              22 E. Mifflin St., Madison, Wisconsin
# 6996         102 West Corporate Dr., Madison, Wisconsin
# 6997         W. Johnson/ N. Frances, Madison, Wisconsin
# 6998      6300 block of Bettys Lane, Madison, Wisconsin
# 6999                      City-Wide, Madison, Wisconsin
#
#                                                  Victim  \
# 0                                                   ...
# 1     n/a                                           ...
# 2     Home Depot                                    ...
# 3     Adult male resident of Madison                ...
# 4                                                   ...
# ...                                                 ...
# 6995                                                NaN
# 6996                               Male age 18, Madison
# 6997                                  Male, 29, Madison
# 6998                                                NaN
# 6999  Motorists, bicyclist, pedestrians, farmers, jo...
#
#                                                 Details  \
# 0     On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1     At approximately 11:42 pm, an officer noted a ...
# 2     On 03/02/2005 at approximately 8:15 am, the Ma...
# 3     At approximately 7:30 am this date, Officers r...
# 4     DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                 ...
# 6995  The suspects weren't quite on the same page wh...
# 6996  The MPD arrested two more teens yesterday in c...
# 6997  On 6/22/13 the victim and friends were walking...
# 6998  On 6/24/13 at 2:03 p.m. several Madison Police...
# 6999  The Madison Police Department has been extreme...
#
#                                     ReleasedBy  Day  Month  Year  Hour  \
# 0     Mike Hanson                                 7     10  2005     4
# 1     Lt Pat Malloy                               3      3  2005     6
# 2     Lt. T. Peterson                             2      3  2005    15
# 3     Lt. Pat Malloy                              3      3  2005    14
# 4     Lieutenant Joe Balles                       4      3  2005    20
# ...                                        ...  ...    ...   ...   ...
# 6995                          PIO Joel DeSpain   20      6  2013    21
# 6996                          PIO Joel DeSpain    8      6  2013     4
# 6997                       Sgt. Michael Hanson   22      6  2013     7
# 6998                       Sgt. Michael Hanson   24      6  2013    19
# 6999                       Sgt. Michael Hanson   26      6  2013    13
#
#             Lat        Long
# 0     43.079849  -89.377004
# 1     33.745647 -117.849324
# 2     43.039938  -89.503098
# 3     43.033631  -89.446744
# 4     43.072397  -89.382550
# ...         ...         ...
# 6995  43.076193  -89.384549
# 6996  43.098630  -89.322269
# 6997  43.072012  -89.395871
# 6998  43.038141  -89.489797
# 6999  43.054045  -89.326017
#
# [7000 rows x 15 columns]

# %%
for i in range(7000,10000):
    
    address = data_new['Address'][i]
    
    data_new['Lat'][i] = get_lat_long(address)[0]
    data_new['Long'][i] = get_lat_long(address)[1]

# %%
data_new.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new[:10000]
# Out:
#       IncidentID                                     IncidentType  \
# 0           7400  Assist Outside Agency
# 1           7401  Arrested Person
# 2           7402  Arrested Person
# 3           7403  Arrested Person
# 4           7404  Information
# ...          ...                                              ...
# 9995       18478                               Attempted Homicide
# 9996       18479                                          Robbery
# 9997       18480                                Weapons Violation
# 9998       18481                                Weapons Violation
# 9999       18482                                          Robbery
#
#                                              CaseNumber  \
# 0     2005-13680                                    ...
# 1     2005-22647                                    ...
# 2     2005-22345                                    ...
# 3     2005-22688                                    ...
# 4     2005-999999                                   ...
# ...                                                 ...
# 9995                                        2016-414818
# 9996                                        2016-414870
# 9997                                        2016-413177
# 9998                                        2016-413844
# 9999                                        2016-414936
#
#                                                 Suspect  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995  Hasson J. Williams, age 29, Madison\r\nSuspect...
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999  Male, white, 5'6" to 5'7", wearing dark clothi...
#
#                                                Arrested  \
# 0                                                   ...
# 1     Tony R Markovitch, 20 years old, 301 Knutson D...
# 2     Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3     Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                   ...
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997  Terrell R. Cargile, age 33, Madison\r\nSuspect...
# 9998  Jerrod J. Ragland, age 25, Madison\r\nSuspect ...
# 9999                                                NaN
#
#                                                 Address  \
# 0     700 Block of E. Washington Ave., Madison, Wisc...
# 1       First St & E Washington Ave, Madison, Wisconsin
# 2                  8 New Berm Court, Madison, Wisconsin
# 3                    4300 Lumley Rd, Madison, Wisconsin
# 4             211 S. Carroll Street, Madison, Wisconsin
# ...                                                 ...
# 9995                      Wright St, Madison, Wisconsin
# 9996         1700 block Fordem Ave., Madison, Wisconsin
# 9997        3019 E. Washington Ave., Madison, Wisconsin
# 9998                 W. Johnson St., Madison, Wisconsin
# 9999        2604 E. Washington Ave., Madison, Wisconsin
#
#                                                  Victim  \
# 0                                                   ...
# 1     n/a                                           ...
# 2     Home Depot                                    ...
# 3     Adult male resident of Madison                ...
# 4                                                   ...
# ...                                                 ...
# 9995                              Male, age 30, Madison
# 9996                            Female, age 22, Madison
# 9997                            Female, age 31, Madison
# 9998                                                NaN
# 9999                                                NaN
#
#                                                 Details  \
# 0     On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1     At approximately 11:42 pm, an officer noted a ...
# 2     On 03/02/2005 at approximately 8:15 am, the Ma...
# 3     At approximately 7:30 am this date, Officers r...
# 4     DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                 ...
# 9995  On 11/20/16 at approximately 8:57 PM, the Madi...
# 9996  &nbsp;A Sunday night dog walk turned into a mu...
# 9997  &nbsp;The MPD recovered a handgun a suspect hi...
# 9998  &nbsp;A driver, who ran a red light downtown S...
# 9999  &nbsp;A man wielding a knife held up Papa John...
#
#                                     ReleasedBy  Day  Month  Year  Hour  \
# 0     Mike Hanson                                 7     10  2005     4
# 1     Lt Pat Malloy                               3      3  2005     6
# 2     Lt. T. Peterson                             2      3  2005    15
# 3     Lt. Pat Malloy                              3      3  2005    14
# 4     Lieutenant Joe Balles                       4      3  2005    20
# ...                                        ...  ...    ...   ...   ...
# 9995                   Sgt. Shannon Blackamore   21     11  2016     3
# 9996                          PIO Joel DeSpain   21     11  2016     3
# 9997                          PIO Joel DeSpain   19     11  2016    15
# 9998                          PIO Joel DeSpain   20     11  2016     4
# 9999                          PIO Joel DeSpain   21     11  2016     6
#
#             Lat        Long
# 0     43.079849  -89.377004
# 1     33.745647 -117.849324
# 2     43.039938  -89.503098
# 3     43.033631  -89.446744
# 4     43.072397  -89.382550
# ...         ...         ...
# 9995  43.122347  -89.330385
# 9996  43.094318  -89.364199
# 9997  43.103635  -89.341810
# 9998  43.072040  -89.397469
# 9999  43.100831  -89.348909
#
# [10000 rows x 15 columns]

# %%
for i in range(10000,13000):
    
    address = data_new['Address'][i]
    
    data_new['Lat'][i] = get_lat_long(address)[0]
    data_new['Long'][i] = get_lat_long(address)[1]

# %%
data_new.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new[:13000]
# Out:
#        IncidentID                                     IncidentType  \
# 0            7400  Assist Outside Agency
# 1            7401  Arrested Person
# 2            7402  Arrested Person
# 3            7403  Arrested Person
# 4            7404  Information
# ...           ...                                              ...
# 12995       25473                                            Theft
# 12996       25474                                 Traffic Incident
# 12997       25475                                            Theft
# 12998       25476                                Weapons Violation
# 12999       25477                                Weapons Violation
#
#                                               CaseNumber Suspect  \
# 0      2005-13680                                    ...     NaN
# 1      2005-22647                                    ...     NaN
# 2      2005-22345                                    ...     NaN
# 3      2005-22688                                    ...     NaN
# 4      2005-999999                                   ...     NaN
# ...                                                  ...     ...
# 12995                                        2020-146504     NaN
# 12996                                        2020-146582     NaN
# 12997                                        2020-901623     NaN
# 12998                                        2020-147888     NaN
# 12999                                        2020-148543     NaN
#
#                                                 Arrested  \
# 0                                                    ...
# 1      Tony R Markovitch, 20 years old, 301 Knutson D...
# 2      Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3      Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                    ...
# ...                                                  ...
# 12995                                                NaN
# 12996                                                NaN
# 12997                                                NaN
# 12998                                                NaN
# 12999                                                NaN
#
#                                                  Address  \
# 0      700 Block of E. Washington Ave., Madison, Wisc...
# 1        First St & E Washington Ave, Madison, Wisconsin
# 2                   8 New Berm Court, Madison, Wisconsin
# 3                     4300 Lumley Rd, Madison, Wisconsin
# 4              211 S. Carroll Street, Madison, Wisconsin
# ...                                                  ...
# 12995              Wintergreen Drive, Madison, Wisconsin
# 12996                  E. Gorham St., Madison, Wisconsin
# 12997           1117 N. Sherman Ave., Madison, Wisconsin
# 12998  1000 block North Sherman Ave., Madison, Wisconsin
# 12999  S. Ingersoll St at Jenifer St, Madison, Wisconsin
#
#                                                   Victim  \
# 0                                                    ...
# 1      n/a                                           ...
# 2      Home Depot                                    ...
# 3      Adult male resident of Madison                ...
# 4                                                    ...
# ...                                                  ...
# 12995                                                NaN
# 12996                                                NaN
# 12997                                                NaN
# 12998                                                NaN
# 12999                                                NaN
#
#                                                  Details  \
# 0      On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1      At approximately 11:42 pm, an officer noted a ...
# 2      On 03/02/2005 at approximately 8:15 am, the Ma...
# 3      At approximately 7:30 am this date, Officers r...
# 4      DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                  ...
# 12995  A Wintergreen Dr. resident used a smart key to...
# 12996  A MPD officer was using a laser to monitor inb...
# 12997  MPD crime analysts have detected similarities ...
# 12998  &nbsp;MPD’s Violent Crime Unit, along with Nor...
# 12999  Multiple callers called 911 to report shots fi...
#
#                                      ReleasedBy  Day  Month  Year  Hour  \
# 0      Mike Hanson                                 7     10  2005     4
# 1      Lt Pat Malloy                               3      3  2005     6
# 2      Lt. T. Peterson                             2      3  2005    15
# 3      Lt. Pat Malloy                              3      3  2005    14
# 4      Lieutenant Joe Balles                       4      3  2005    20
# ...                                         ...  ...    ...   ...   ...
# 12995                          PIO Joel DeSpain   22      4  2020    11
# 12996                          PIO Joel DeSpain   22      4  2020    13
# 12997                          PIO Joel DeSpain   22      4  2020    16
# 12998                          PIO Joel DeSpain   23      4  2020    17
# 12999                        Sgt. Joseph Engler   24      4  2020     4
#
#              Lat        Long
# 0      43.079849  -89.377004
# 1      33.745647 -117.849324
# 2      43.039938  -89.503098
# 3      43.033631  -89.446744
# 4      43.072397  -89.382550
# ...          ...         ...
# 12995  43.107221  -89.294424
# 12996  43.083863  -89.378840
# 12997  43.112317  -89.363072
# 12998  43.110792  -89.364212
# 12999  43.081358  -89.365250
#
# [13000 rows x 15 columns]

# %%
for i in range(13000,data_new.shape[0]+1):
    
    address = data_new['Address'][i]
    
    data_new['Lat'][i] = get_lat_long(address)[0]
    data_new['Long'][i] = get_lat_long(address)[1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 14136 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-aae268b3bd88> in <module>
#       1 for i in range(13000,data_new.shape[0]+1):
#       2
# ----> 3     address = data_new['Address'][i]
#       4
#       5     data_new['Lat'][i] = get_lat_long(address)[0]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     351                     return self._range.index(new_key)
#     352                 except ValueError as err:
# --> 353                     raise KeyError(key) from err
#     354             raise KeyError(key)
#     355         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 14136

# %%
data_new.to_csv('geo_df.csv', index = False)

# %%
data_new = pd.read_csv('geo_df.csv')
data_new
# Out:
#        IncidentID                                     IncidentType  \
# 0            7400  Assist Outside Agency
# 1            7401  Arrested Person
# 2            7402  Arrested Person
# 3            7403  Arrested Person
# 4            7404  Information
# ...           ...                                              ...
# 14131       28608                                          Robbery
# 14132       28609                               Attempted Homicide
# 14133       28610                                      Information
# 14134       28611                              Fight (In Progress)
# 14135       28612                                      Information
#
#                                               CaseNumber  \
# 0      2005-13680                                    ...
# 1      2005-22647                                    ...
# 2      2005-22345                                    ...
# 3      2005-22688                                    ...
# 4      2005-999999                                   ...
# ...                                                  ...
# 14131                                        2021-410423
# 14132                                        2021-407981
# 14133                                        2021-411747
# 14134                                        2021-412832
# 14135                                        0000-000000
#
#                                                  Suspect  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14131  Male described as 6 feet tall, slender, with a...
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                 Arrested  \
# 0                                                    ...
# 1      Tony R Markovitch, 20 years old, 301 Knutson D...
# 2      Martell D. Britton m/b 05-03-85\r\r\nCharge:  ...
# 3      Twainesse L Peavy, 26 yrs old, 2317 Fish Hatch...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                     Tokiee D. Sole
# 14133                                                NaN
# 14134  Aaron Mixon, 24-year-old\r\n\r\nNathan Dougher...
# 14135                                                NaN
#
#                                                  Address  \
# 0      700 Block of E. Washington Ave., Madison, Wisc...
# 1        First St & E Washington Ave, Madison, Wisconsin
# 2                   8 New Berm Court, Madison, Wisconsin
# 3                     4300 Lumley Rd, Madison, Wisconsin
# 4              211 S. Carroll Street, Madison, Wisconsin
# ...                                                  ...
# 14131           3700 Frosted Leaf Dr, Madison, Wisconsin
# 14132           5800 block Balsam Rd, Madison, Wisconsin
# 14133          Esker Trl/Lilyview Ln, Madison, Wisconsin
# 14134                 200 N First St, Madison, Wisconsin
# 14135              1710 Mckenna Blvd, Madison, Wisconsin
#
#                                                   Victim  \
# 0                                                    ...
# 1      n/a                                           ...
# 2      Home Depot                                    ...
# 3      Adult male resident of Madison                ...
# 4                                                    ...
# ...                                                  ...
# 14131                                                NaN
# 14132                                                NaN
# 14133                                                NaN
# 14134                                                NaN
# 14135                                                NaN
#
#                                                  Details  \
# 0      On 2/6/05 at approximately 10:33 p.m. Officer ...
# 1      At approximately 11:42 pm, an officer noted a ...
# 2      On 03/02/2005 at approximately 8:15 am, the Ma...
# 3      At approximately 7:30 am this date, Officers r...
# 4      DELIVERY NOTICES FOR UNPAID PARKING TICKETS\r\...
# ...                                                  ...
# 14131  Madison Police officers were dispatched to the...
# 14132  On 10/10/2021 at approximately 3:50 a.m., Madi...
# 14133  On October 12th, 2021 at approximately 6:43 PM...
# 14134  Madison Police Officers responded to 200 N Fir...
# 14135  The Madison Police Department’s West District ...
#
#                                      ReleasedBy  Day  Month  Year  Hour  \
# 0      Mike Hanson                                 7     10  2005     4
# 1      Lt Pat Malloy                               3      3  2005     6
# 2      Lt. T. Peterson                             2      3  2005    15
# 3      Lt. Pat Malloy                              3      3  2005    14
# 4      Lieutenant Joe Balles                       4      3  2005    20
# ...                                         ...  ...    ...   ...   ...
# 14131                    Lt. Michael Richardson   12     10  2021     7
# 14132                         P.O. Hunter Lisko   10     10  2021     9
# 14133                        PIO Julie Laundrie   12     10  2021    24
# 14134                       P.O. Ryan Kimberley   13     10  2021    22
# 14135                       P.O. Ryan Kimberley   14     10  2021     5
#
#              Lat        Long
# 0      43.079849  -89.377004
# 1      33.745647 -117.849324
# 2      43.039938  -89.503098
# 3      43.033631  -89.446744
# 4      43.072397  -89.382550
# ...          ...         ...
# 14131  43.004556  -89.507324
# 14132  43.031092  -89.480088
# 14133  43.023937  -89.518707
# 14134  43.093419  -89.361963
# 14135  43.033647  -89.497620
#
# [14136 rows x 15 columns]
